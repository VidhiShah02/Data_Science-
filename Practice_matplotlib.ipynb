# %%
#Import Pandas,Numpy,Matplotlib in jupyter notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Create a simple plot using plt.plot()
plt.plot();

# %%
# Plot a single Python list
plt.plot([10,9,33,50]);

# %%
# Create two lists, one called X, one called y, each with 5 numbers in them
x=pd.Series([11,50,79,200])
y=pd.Series([10,20,30,100])

# %%
# Plot X & y 
#There's another way to create plots with Matplotlib, it's known as the object-orientated (OO) method.
plt.plot(x,y);

# %%
# Create a plot using plt.subplots()
plt.subplots();

# %%
# Create  plots
fig,ax=plt.subplots();
ax.plot(x,y);

# %%
# Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable 
X=np.random.random(100)

# %%
# Create a plot using plt.subplots() and plot X versus X^2 (X squared)
fig,ax=plt.subplots()
ax.plot(X,X**2);

# %% [markdown]
# We'll start with scatter plots.

# %%
# Create a scatter plot of X versus the exponential of X (np.exp(X))
plt.scatter(x,np.exp(x));

# %%
# Create a scatter plot of X versus np.sin(X)
plt.scatter(x,np.sin(x));

# %%
food={"Pasta":220,"Maggie":100,"Noodles":70,"Milkshake":150}

# %%
# Create a bar graph where the x-axis is the keys of the dictionary
# and the y-axis is the values of the dictionary
# Add a title, xlabel and ylabel to the plot
fig,ax=plt.subplots()
ax.bar(food.keys(),food.values())
ax.set(title="Foodiezz",xlabel="Food",ylabel="Prices")
# Out:
# [Text(0.5, 1.0, 'Foodiezz'), Text(0.5, 0, 'Food'), Text(0, 0.5, 'Prices')]

# %%
# Make the same plot as above, except this time make the bars go horizontal
fig,ax=plt.subplots()
ax.barh(list(food.keys()),list(food.values()))
ax.set(title="Foodiezz",xlabel="Prices",ylabel="Food")
# Out:
# [Text(0.5, 1.0, 'Foodiezz'), Text(0.5, 0, 'Prices'), Text(0, 0.5, 'Food')]

# %%
# Create a random NumPy array of 1000 random numbers
np.random.seed(4)
rnumber=np.random.randn(1000)

# %%
# Create a histogram plot of random number

plt.hist(rnumber);

# %%
Xn=np.random.random(1000)
plt.hist(Xn);

# %%
# Create an empty subplot with 2 rows and 2 columns (4 subplots total)
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,
                    ncols=2)

# %%
# Plot X versus X/2 on the top left axes


# Plot a scatter plot of 10 random numbers on each axis on the top right subplot


# Plot a bar graph of the favourite food keys and values on the bottom left subplot


# Plot a histogram of 1000 random normally distributed numbers on the bottom right subplot
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,
                                       ncols=2,
                                      figsize=(10,5))
ax1.plot(x,x/2);
ax2.scatter(np.random.randn(10),np.random.randn(10));
ax3.bar(list(food.keys()),list(food.values()));
ax4.hist(np.random.random(1000),bins=5);

# %%
# Import the 'car-sales.csv' into a DataFame called car_sales and view
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Try to plot the 'Price' column using the plot() function
plt.plot("Price");
#non numeric values in Price

# %%
# Remove the symbols, the final two numbers from the 'Price' column and convert it to numbers
car_sales["Price"]=car_sales["Price"].str.replace("[\$\,\.]","").astype(int);
car_sales["Price"]=car_sales["Price"]/100;
car_sales["Price"].dtype
# Out:
# dtype('float64')

# %%
# Add a column called 'Total Sales' to car_sales which cumulatively adds the 'Price' column
car_sales["Total Sales"]=car_sales["Price"].cumsum();
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Total Sales
# 0  Toyota  White         150043      4   4000.0       4000.0
# 1   Honda    Red          87899      4   5000.0       9000.0
# 2  Toyota   Blue          32549      3   7000.0      16000.0
# 3     BMW  Black          11179      5  22000.0      38000.0
# 4  Nissan  White         213095      4   3500.0      41500.0
# 5  Toyota  Green          99213      4   4500.0      46000.0
# 6   Honda   Blue          45698      4   7500.0      53500.0
# 7   Honda   Blue          54738      4   7000.0      60500.0
# 8  Toyota  White          60000      4   6250.0      66750.0
# 9  Nissan  White          31600      4   9700.0      76450.0

# %%
# Add a column called 'Sale Date' which lists a series of successive dates starting from today (your today)
car_sales["Sale Date"]=pd.date_range("18/11/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000.0       4000.0 2020-11-18
# 1   Honda    Red          87899      4   5000.0       9000.0 2020-11-19
# 2  Toyota   Blue          32549      3   7000.0      16000.0 2020-11-20
# 3     BMW  Black          11179      5  22000.0      38000.0 2020-11-21
# 4  Nissan  White         213095      4   3500.0      41500.0 2020-11-22
# 5  Toyota  Green          99213      4   4500.0      46000.0 2020-11-23
# 6   Honda   Blue          45698      4   7500.0      53500.0 2020-11-24
# 7   Honda   Blue          54738      4   7000.0      60500.0 2020-11-25
# 8  Toyota  White          60000      4   6250.0      66750.0 2020-11-26
# 9  Nissan  White          31600      4   9700.0      76450.0 2020-11-27

# %%
# Use the plot() function to plot the 'Sale Date' column versus the 'Total Sales' column
car_sales.plot(x="Sale Date",y="Total Sales");

# %%
# Create a scatter plot of the 'Odometer (KM)' and 'Price' column using the plot() function
plt.scatter(car_sales["Odometer (KM)"],car_sales["Price"]);

# %%
# Create a NumPy array of random numbers of size (10, 4) and save it to X
X=np.random.random(size=(10,4))
# Turn the NumPy array X into a DataFrame with columns
df=pd.DataFrame(X,columns=['a', 'b', 'c', 'd'])
# Create a bar graph of the DataFrame
df.plot(kind="bar");

# %%
# Create a bar graph of the 'Make' and 'Odometer (KM)' columns in the car_sales DataFrame
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar");

# %%
# Create a histogram of the 'Odometer (KM)' column
car_sales.hist("Odometer (KM)");

# %%
# Create a histogram of the 'Price' column with 20 bins
car_sales.hist("Price",bins=20);

# %%
# Import "heart-disease.csv" and save it to the variable "heart_disease"
heart_disease=pd.read_csv("heart-disease.csv")
len(heart_disease)
# Out:
# 303

# %%
# View the first 10 rows of the heart_disease DataFrame
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1
# 7   0     3       1
# 8   0     3       1
# 9   0     2       1

# %%
# Create a histogram of the "age" column with 50 bins
heart_disease.hist("age",bins=50);

# %%
# Call plot.hist() on the heart_disease DataFrame and toggle the
# "subplots" parameter to True
heart_disease.plot.hist(subplots=True);

# %%
# Call the same line of code from above except change the "figsize" parameter
# to be (10, 30)
heart_disease.plot.hist(subplots=True,figsize=(10,30));

# %%
#to have dataframe of patient above 50 years
over_50=heart_disease[heart_disease["age"]>50]

# %%
#Figure
fig,ax=plt.subplots(figsize=(10,5));

scatter=ax.scatter(y=over_50["chol"],
                  x=over_50["age"],
                  c=over_50["target"])

#for legend in the graph
ax.legend(*scatter.legend_elements(),title="target")

#for all the labels and title in the graph
ax.set(xlabel="Age",ylabel="Cholesterol",title="Heart Disease and Cholesterol Levels")

#for adding horizontal line the graph
ax.axhline(y=over_50["chol"].mean(),linestyle="--");

# %%
# Reproduce the same figure as above with the "seaborn-whitegrid" style
#Figure
#for the different style
plt.style.use("seaborn-whitegrid")
fig,ax=plt.subplots(figsize=(10,5));

scatter=ax.scatter(y=over_50["chol"],
                  x=over_50["age"],
                  c=over_50["target"]
                  )
#for legend in the graph
ax.legend(*scatter.legend_elements(),title="target")

#for all the labels and title in the graph
ax.set(xlabel="Age",ylabel="Cholesterol",title="Heart Disease and Cholesterol Levels")

#for adding horizontal line the graph
ax.axhline(y=over_50["chol"].mean(),linestyle="--");

# %%
# Replot the same figure as above except change the "cmap" parameter
# of scatter() to "winter"
# Also change the "color" parameter of axhline() to "red"
#Figure
#for the different style
plt.style.use("seaborn-whitegrid")
fig,ax=plt.subplots(figsize=(10,5));

scatter=ax.scatter(y=over_50["chol"],
                  x=over_50["age"],
                  c=over_50["target"],
                   cmap="winter")
                  
#for legend in the graph
ax.legend(*scatter.legend_elements(),title="target")

#for all the labels and title in the graph
ax.set(xlabel="Age",ylabel="Cholesterol",title="Heart Disease and Cholesterol Levels")

#for adding horizontal line the graph
ax.axhline(y=over_50["chol"].mean(),linestyle="--",color="red");

# %%
# Save the current figure using savefig(), the file name can be anything you want
fig.savefig("heart-disease-and-cholesterol-analysis-plot-saved-wit-code.png")
